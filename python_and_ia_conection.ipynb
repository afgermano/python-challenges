# %% [markdown]
# ## Rodando a sua IA no Google Colab

# %% [markdown]
# Configuração e Chave de API

# %%
# Importação de bibliotecas necessárias
import os
from google.colab import userdata
from google import genai

# Configuração da chave de API utilizando os Secrets do Colab
# Certifique-se de que o nome 'GEMINI_ANAF' está configurado no menu lateral (ícone de chave)
os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_ANAF')

# Inicialização do cliente oficial da API Gemini
client = genai.Client()

# %% [markdown]
# Teste de Geração Simples

# %%
# Geração de conteúdo isolada (Single-turn)
# O modelo 'gemini-2.5-flash' é otimizado para velocidade
resposta = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="O que é a inteligência artificial?"
)

# Exibição do texto gerado
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação que se dedica a criar sistemas e máquinas capazes de realizar tarefas que normalmente exigiriam inteligência humana. Em outras palavras, é a busca por dotar computadores com a capacidade de pensar, aprender, raciocinar, perceber, resolver problemas e tomar decisões de maneira semelhante, ou até superior, aos humanos.
#
# ### Principais Objetivos da IA:
#
# 1.  **Aprender:** Adquirir conhecimento e habilidades a partir de dados e experiências, sem ser explicitamente programado para cada cenário (isso é o cerne do Machine Learning).
# 2.  **Raciocinar:** Utilizar lógica e regras para tirar conclusões e fazer inferências.
# 3.  **Perceber:** Interpretar informações sensoriais (visão, audição, etc.) do ambiente.
# 4.  **Compreender Linguagem Natural:** Processar e gerar linguagem humana (escrita e falada).
# 5.  **Resolver Problemas:** Encontrar soluções para desafios complexos.
# 6.  **Manipular e Mover:** Interagir com o mundo físico, em robótica.
#
# ### Como a IA Funciona (Abordagens Comuns):
#
# *   **Machine Learning (Aprendizado de Máquina):** É o principal motor da IA moderna. Em vez de ser explicitamente programado com cada regra, um algoritmo de ML é "treinado" com grandes volumes de dados. Através desse treinamento, ele aprende a identificar padrões, fazer previsões ou tomar decisões.
#     *   **Aprendizado Supervisionado:** Treinado com dados que já têm a resposta correta (ex: fotos de gatos e cachorros rotuladas).
#     *   **Aprendizado Não Supervisionado:** Encontra padrões e estruturas em dados sem rótulos (ex: agrupando clientes por comportamento de compra).
#     *   **Aprendizado por Reforço:** Aprende através de tentativa e erro, recebendo "recompensas" por ações corretas e "penalidades" por erros (ex: um programa de xadrez que aprende a jogar melhor a cada partida).
# *   **Deep Learning (Aprendizado Profundo):** Um subcampo do Machine Learning que utiliza redes neurais artificiais com muitas camadas ("profundas") para analisar dados com uma arquitetura inspirada no cérebro humano. É extremamente eficaz para tarefas como reconhecimento de imagens, voz e linguagem natural.
# *   **Processamento de Linguagem Natural (PNL/NLP):** Permite que as máquinas entendam, interpretem e gerem linguagem humana. É o que faz assistentes virtuais como a Siri e a Alexa funcionarem, e também é crucial para tradutores automáticos e chatbots.
# *   **Visão Computacional:** Capacita as máquinas a "ver" e interpretar imagens e vídeos, identificando objetos, pessoas, cenas e até emoções.
# *   **Sistemas Especialistas:** Programas que simulam o conhecimento e o raciocínio de um especialista humano em um domínio específico.
#
# ### Tipos de IA:
#
# 1.  **IA Fraca (Narrow AI ou Weak AI):** É a maioria da IA que vemos hoje. É projetada e treinada para uma tarefa específica. Exemplos incluem assistentes de voz, sistemas de recomendação de filmes, carros autônomos (em seu estado atual), programas de xadrez, filtros de spam e reconhecimento facial. Ela não possui consciência ou inteligência geral.
# 2.  **IA Forte (General AI ou Strong AI / AGI):** É uma IA hipotética que teria a capacidade intelectual de um ser humano em qualquer tarefa, ou seja, poderia aprender a fazer qualquer coisa que um ser humano pode fazer. Ela teria consciência, autoconsciência e a capacidade de aplicar sua inteligência a uma ampla gama de problemas. Ainda é um objetivo de pesquisa e não existe atualmente.
# 3.  **Superinteligência Artificial (ASI):** Uma IA hipotética que superaria a inteligência humana em todos os aspectos, incluindo criatividade, resolução de problemas e habilidades sociais. Ainda mais distante da realidade do que a AGI.
#
# ### Exemplos de Aplicações da IA:
#
# *   **Assistentes Virtuais:** Siri, Alexa, Google Assistant.
# *   **Carros Autônomos:** Sistemas de direção sem motorista.
# *   **Recomendação de Produtos/Conteúdo:** Netflix, Amazon, Spotify.
# *   **Diagnóstico Médico:** Análise de exames para identificar doenças.
# *   **Detecção de Fraudes:** Em bancos e transações financeiras.
# *   **Tradução Automática:** Google Translate.
# *   **Reconhecimento Facial e de Voz:** Desbloqueio de celulares, segurança.
# *   **Chatbots:** Atendimento ao cliente automatizado.
# *   **Geração de Conteúdo:** Ferramentas como ChatGPT (texto), DALL-E, Midjourney (imagens).
#
# A IA é uma área em constante evolução, com o potencial de transformar praticamente todos os aspectos da vida humana, desde a medicina e a educação até o transporte e a indústria.

# %% [markdown]
# Chat interativo (Com histórico de prompts)

# %%
# Criação de uma sessão de chat para manter o contexto da conversa
chat = client.chats.create(model="gemini-2.5-flash")

# Início do loop de interação
print("Digite 'Fim' para encerrar o chat.")
prompt = input("Digite a sua pergunta: ")

while prompt.strip().lower() != "fim":
    # Envio da mensagem e recepção da resposta
    resposta = chat.send_message(prompt)
    print(f"\nAI: {resposta.text}\n")

    # Solicitação da próxima pergunta
    prompt = input("Digite a sua pergunta: ")
# Out:
# Digite 'Fim' para encerrar o chat.
# Digite a sua pergunta: O que é Python?
#
# AI: Python é uma **linguagem de programação de alto nível, interpretada, de propósito geral e orientada a objetos**, conhecida por sua **sintaxe clara e legível**, o que a torna uma das linguagens mais populares e acessíveis para iniciantes, mas também extremamente poderosa para profissionais.
#
# Vamos detalhar alguns pontos chave:
#
# 1.  **Linguagem de Alto Nível:** Isso significa que ela se aproxima mais da linguagem humana (inglês) do que da linguagem de máquina. Você não precisa se preocupar com os detalhes de baixo nível do hardware, facilitando a escrita e o entendimento do código.
#
# 2.  **Interpretada:** Ao contrário de linguagens compiladas (como C++ ou Java, que precisam ser traduzidas para um executável antes de rodar), o código Python é executado linha por linha por um "interpretador". Isso acelera o processo de desenvolvimento e depuração.
#
# 3.  **De Propósito Geral:** Python não é especializada para uma única área. Ela pode ser usada para uma vasta gama de aplicações, desde desenvolvimento web até inteligência artificial.
#
# 4.  **Sintaxe Simples e Legível:** Uma das características mais marcantes de Python é o foco na legibilidade. Seu código se parece quase com pseudo-código ou sentenças em inglês, o que facilita o aprendizado, a escrita e a manutenção. A indentação (espaços no início da linha) é semanticamente importante, forçando um estilo de código limpo.
#
# 5.  **Orientada a Objetos (OO):** Python suporta o paradigma de programação orientada a objetos, permitindo que os desenvolvedores criem código modular e reutilizável através de classes e objetos.
#
# 6.  **Open Source e Comunidade Forte:** Python é de código aberto, o que significa que é gratuita para usar e distribuir. Ela tem uma comunidade global enorme e ativa que contribui para seu desenvolvimento, cria bibliotecas, frameworks e oferece suporte.
#
# ---
#
# ### Onde Python é Usado?
#
# Devido à sua versatilidade, Python é empregado em diversas áreas:
#
# *   **Desenvolvimento Web:** Com frameworks como Django e Flask, é possível construir sites e aplicações web complexas e escaláveis.
# *   **Análise de Dados e Ciência de Dados:** É a linguagem dominante nessa área, com bibliotecas poderosas como Pandas, NumPy e SciPy para manipulação e análise de grandes volumes de dados.
# *   **Inteligência Artificial e Machine Learning:** TensorFlow, Keras e PyTorch são frameworks populares de Python para criar modelos de IA e aprendizado de máquina.
# *   **Automação de Tarefas e Scripting:** Excelente para escrever scripts que automatizam tarefas repetitivas no sistema operacional ou em outras aplicações.
# *   **Desenvolvimento de Jogos:** Embora não seja a principal, Pygame é uma biblioteca popular para criar jogos 2D.
# *   **Aplicações Desktop:** Bibliotecas como Tkinter, PyQt e Kivy permitem criar interfaces gráficas de usuário (GUI).
# *   **DevOps e Infraestrutura:** Usada para gerenciar e automatizar a infraestrutura de servidores.
# *   **Educação:** Devido à sua facilidade de aprendizado, é frequentemente a primeira linguagem ensinada em cursos de programação.
#
# ---
#
# ### Exemplo Simples de Código Python:
#
# Para exibir a mensagem "Olá, Mundo!":
#
# ```python
# print("Olá, Mundo!")
# ```
#
# Este simples exemplo demonstra a clareza e concisão da linguagem.
#
# Em resumo, Python é uma linguagem de programação extremamente poderosa, flexível e fácil de aprender, que se tornou essencial em muitas indústrias e é uma excelente escolha tanto para quem está começando quanto para desenvolvedores experientes.
#
# Digite a sua pergunta: fim
# [UserContent(
#    parts=[
#      Part(
#        text='O que é Python?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""Python é uma **linguagem de programação de alto nível, interpretada, de propósito geral e orientada a objetos**, conhecida por sua **sintaxe clara e legível**, o que a torna uma das linguagens mais populares e acessíveis para iniciantes, mas também extremamente poderosa para profissionais.
#
#  Vamos detalhar alguns pontos chave:
#
#  1.  **Linguagem de Alto Nível:** Isso significa que ela se aproxima mais da linguagem humana (inglês) do que da linguagem de máquina. Você não precisa se preocupar com os detalhes de baixo nível do hardware, facilitando a escrita e o entendimento do código.
#
#  2.  **Interpretada:** Ao contrário de linguagens compiladas (como C++ ou Java, que precisam ser traduzidas para um executável antes de rodar), o código Python é executado linha por linha por um "interpretador". Isso acelera o processo de desenvolvimento e depuração.
#
#  3.  **De Propósito Geral:** Python não é especializada para uma única área. Ela pode ser usada para uma vasta gama de aplicações, desde desenvolvimento web até inteligência artificial.
#
#  4.  **Sintaxe Simples e Legível:** Uma das características mais marcantes de Python é o foco na legibilidade. Seu código se parece quase com pseudo-código ou sentenças em inglês, o que facilita o aprendizado, a escrita e a manutenção. A indentação (espaços no início da linha) é semanticamente importante, forçando um estilo de código limpo.
#
#  5.  **Orientada a Objetos (OO):** Python suporta o paradigma de programação orientada a objetos, permitindo que os desenvolvedores criem código modular e reutilizável através de classes e objetos.
#
#  6.  **Open Source e Comunidade Forte:** Python é de código aberto, o que significa que é gratuita para usar e distribuir. Ela tem uma comunidade global enorme e ativa que contribui para seu desenvolvimento, cria bibliotecas, frameworks e oferece suporte.
#
#  ---
#
#  ### Onde Python é Usado?
#
#  Devido à sua versatilidade, Python é empregado em diversas áreas:
#
#  *   **Desenvolvimento Web:** Com frameworks como Django e Flask, é possível construir sites e aplicações web complexas e escaláveis.
#  *   **Análise de Dados e Ciência de Dados:** É a linguagem dominante nessa área, com bibliotecas poderosas como Pandas, NumPy e SciPy para manipulação e análise de grandes volumes de dados.
#  *   **Inteligência Artificial e Machine Learning:** TensorFlow, Keras e PyTorch são frameworks populares de Python para criar modelos de IA e aprendizado de máquina.
#  *   **Automação de Tarefas e Scripting:** Excelente para escrever scripts que automatizam tarefas repetitivas no sistema operacional ou em outras aplicações.
#  *   **Desenvolvimento de Jogos:** Embora não seja a principal, Pygame é uma biblioteca popular para criar jogos 2D.
#  *   **Aplicações Desktop:** Bibliotecas como Tkinter, PyQt e Kivy permitem criar interfaces gráficas de usuário (GUI).
#  *   **DevOps e Infraestrutura:** Usada para gerenciar e automatizar a infraestrutura de servidores.
#  *   **Educação:** Devido à sua facilidade de aprendizado, é frequentemente a primeira linguagem ensinada em cursos de programação.
#
#  ---
#
#  ### Exemplo Simples de Código Python:
#
#  Para exibir a mensagem "Olá, Mundo!":
#
#  ```python
#  print("Olá, Mundo!")
#  ```
#
#  Este simples exemplo demonstra a clareza e concisão da linguagem.
#
#  Em resumo, Python é uma linguagem de programação extremamente poderosa, flexível e fácil de aprender, que se tornou essencial em muitas indústrias e é uma excelente escolha tanto para quem está começando quanto para desenvolvedores experientes."""
#      ),
#    ],
#    role='model'
#  )]

# %%
#Exibe o histórico de prompts
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é Python?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""Python é uma **linguagem de programação de alto nível, interpretada, de propósito geral e orientada a objetos**, conhecida por sua **sintaxe clara e legível**, o que a torna uma das linguagens mais populares e acessíveis para iniciantes, mas também extremamente poderosa para profissionais.
#
#  Vamos detalhar alguns pontos chave:
#
#  1.  **Linguagem de Alto Nível:** Isso significa que ela se aproxima mais da linguagem humana (inglês) do que da linguagem de máquina. Você não precisa se preocupar com os detalhes de baixo nível do hardware, facilitando a escrita e o entendimento do código.
#
#  2.  **Interpretada:** Ao contrário de linguagens compiladas (como C++ ou Java, que precisam ser traduzidas para um executável antes de rodar), o código Python é executado linha por linha por um "interpretador". Isso acelera o processo de desenvolvimento e depuração.
#
#  3.  **De Propósito Geral:** Python não é especializada para uma única área. Ela pode ser usada para uma vasta gama de aplicações, desde desenvolvimento web até inteligência artificial.
#
#  4.  **Sintaxe Simples e Legível:** Uma das características mais marcantes de Python é o foco na legibilidade. Seu código se parece quase com pseudo-código ou sentenças em inglês, o que facilita o aprendizado, a escrita e a manutenção. A indentação (espaços no início da linha) é semanticamente importante, forçando um estilo de código limpo.
#
#  5.  **Orientada a Objetos (OO):** Python suporta o paradigma de programação orientada a objetos, permitindo que os desenvolvedores criem código modular e reutilizável através de classes e objetos.
#
#  6.  **Open Source e Comunidade Forte:** Python é de código aberto, o que significa que é gratuita para usar e distribuir. Ela tem uma comunidade global enorme e ativa que contribui para seu desenvolvimento, cria bibliotecas, frameworks e oferece suporte.
#
#  ---
#
#  ### Onde Python é Usado?
#
#  Devido à sua versatilidade, Python é empregado em diversas áreas:
#
#  *   **Desenvolvimento Web:** Com frameworks como Django e Flask, é possível construir sites e aplicações web complexas e escaláveis.
#  *   **Análise de Dados e Ciência de Dados:** É a linguagem dominante nessa área, com bibliotecas poderosas como Pandas, NumPy e SciPy para manipulação e análise de grandes volumes de dados.
#  *   **Inteligência Artificial e Machine Learning:** TensorFlow, Keras e PyTorch são frameworks populares de Python para criar modelos de IA e aprendizado de máquina.
#  *   **Automação de Tarefas e Scripting:** Excelente para escrever scripts que automatizam tarefas repetitivas no sistema operacional ou em outras aplicações.
#  *   **Desenvolvimento de Jogos:** Embora não seja a principal, Pygame é uma biblioteca popular para criar jogos 2D.
#  *   **Aplicações Desktop:** Bibliotecas como Tkinter, PyQt e Kivy permitem criar interfaces gráficas de usuário (GUI).
#  *   **DevOps e Infraestrutura:** Usada para gerenciar e automatizar a infraestrutura de servidores.
#  *   **Educação:** Devido à sua facilidade de aprendizado, é frequentemente a primeira linguagem ensinada em cursos de programação.
#
#  ---
#
#  ### Exemplo Simples de Código Python:
#
#  Para exibir a mensagem "Olá, Mundo!":
#
#  ```python
#  print("Olá, Mundo!")
#  ```
#
#  Este simples exemplo demonstra a clareza e concisão da linguagem.
#
#  Em resumo, Python é uma linguagem de programação extremamente poderosa, flexível e fácil de aprender, que se tornou essencial em muitas indústrias e é uma excelente escolha tanto para quem está começando quanto para desenvolvedores experientes."""
#      ),
#    ],
#    role='model'
#  )]
